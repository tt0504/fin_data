# %% [markdown]
# <a href="https://colab.research.google.com/github/tt0504/fin_data/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
# !pip install fredapi

# %%
from fredapi import Fred

# %%
fred = Fred(api_key='90cfc137d1e792fdd80101d5ed248474')

# %%
mich_data = fred.get_series('MICH', '6/1/2021')

# %%
unrate_data = fred.get_series('UNRATE', '6/1/2021')

# %%
mich_df = mich_data.to_frame(name="MICH")
unrate_df = unrate_data.to_frame(name="UNRATE")
df_merged = pd.merge(mich_df, unrate_df, left_index=True, right_index=True)

# %%
fig, ax = plt.subplots()
ax.plot(df_merged.index, df_merged['MICH'], color="blue", marker="o", label="MICH (Inflation Expectation)")
ax2 = ax.twinx()
ax2.plot(df_merged.index, df_merged['UNRATE'], color="red", marker="x", label="UNRATE (Unemployment Rate)")

# %%
ax.set_ylabel("MICH (%)", color="blue")
ax2.set_ylabel("UNRATE (%)", color="red")
ax.set_title("Expected Inflation (MICH) vs Unemployment Rate (UNRATE)")
fig.legend(loc="upper left", bbox_to_anchor=(0.1, 0.9))
plt.tight_layout()
fig.savefig('MICH_UNRATE_plot.jpg', format='jpeg')

# %%
correlation = df_merged.corr()
print("Correlation Matrix:")
print(correlation)
# Out:
# Correlation Matrix:
#             MICH    UNRATE
# MICH    1.000000 -0.063188
# UNRATE -0.063188  1.000000

# %%
sns.heatmap(correlation, cmap="Blues", annot=True)
plt.title("Correlation Matrix Heatmap")
plt.savefig('MICH_UNRATE_correlation.png', dpi=400)
plt.show()
